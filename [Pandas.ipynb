# %% [markdown]
# <a href="https://colab.research.google.com/github/Khushboo3107-djjk/Machine_Learning_Concepts/blob/main/%5BPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas Library:
# Useful for Data Processing & Analysis

# Pandas Data Frame:
# Two-dimensional tabular data structure with labeled axes (rows and columns).

# Importing libraries
import pandas as pd
import numpy as np

# %%
# 🏡 Loading California Housing Dataset (modern replacement for Boston Housing)
from sklearn.datasets import fetch_california_housing

# Load dataset as a pandas DataFrame
housing_dataset = fetch_california_housing(as_frame=True)

# Convert to DataFrame
boston_df = housing_dataset.frame

boston_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# Check shape and type
print("Shape of dataset:", boston_df.shape)
print("Type of dataset:", type(boston_df))
# Out:
# Shape of dataset: (20640, 9)
# Type of dataset: <class 'pandas.core.frame.DataFrame'>

# %%
# Importing the built-in diabetes dataset from scikit-learn
from sklearn.datasets import load_diabetes

# Load dataset as a DataFrame
diabetes_dataset = load_diabetes(as_frame=True)

# Convert to pandas DataFrame
diabetes_df = diabetes_dataset.frame

# Display first 5 rows
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
# Check number of rows and columns
diabetes_df.shape
# Out:
# (442, 11)

# %%
# Inspecting the diabetes DataFrame
diabetes_df.head()


diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
# Exporting California Housing DataFrame to a CSV file
boston_df.to_csv('california_housing.csv', index=False)

# %%
# Creating a DataFrame with random values
random_df = pd.DataFrame(np.random.rand(20, 10))

random_df.head()
random_df.shape
# Out:
# (20, 10)

# %%
# Inspecting California Housing DataFrame
print("California Housing DataFrame shape:", boston_df.shape)

# First 5 rows
boston_df.head()

# Last 5 rows
boston_df.tail()

# Information about the DataFrame
boston_df.info()

# Finding missing values
boston_df.isnull().sum()

# Inspecting Diabetes DataFrame
print("Diabetes DataFrame shape:", diabetes_df.shape)
diabetes_df.head()

# Summary statistics for Diabetes DataFrame
diabetes_df.describe()
# Out:
# California Housing DataFrame shape: (20640, 9)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# Diabetes DataFrame shape: (442, 11)
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# ...

# %%
# Inspecting the diabetes DataFrame
diabetes_df.head()


# Example: simple description
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -2.511817e-19  1.230790e-17 -2.245564e-16 -4.797570e-17 -1.381499e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123988e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665608e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670422e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564379e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320436e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   3.918434e-17 -5.777179e-18 -9.042540e-18  9.293722e-17  1.130318e-17
# ...

# %%
# Statistical measures for California Housing dataset
print("Count of values per column:")
print(boston_df.count())

print("\nMean values per column:")
print(boston_df.mean())

print("\nStandard deviation per column:")
print(boston_df.std())

print("\nMinimum values per column:")
print(boston_df.min())

print("\nMaximum values per column:")
print(boston_df.max())

print("\nFull summary statistics:")
boston_df.describe()
# Out:
# Count of values per column:
# MedInc         20640
# HouseAge       20640
# AveRooms       20640
# AveBedrms      20640
# Population     20640
# AveOccup       20640
# Latitude       20640
# Longitude      20640
# MedHouseVal    20640
# dtype: int64
#
# Mean values per column:
# MedInc            3.870671
# HouseAge         28.639486
# AveRooms          5.429000
# AveBedrms         1.096675
# Population     1425.476744
# AveOccup          3.070655
# Latitude         35.631861
# Longitude      -119.569704
# MedHouseVal       2.068558
# dtype: float64
#
# Standard deviation per column:
# MedInc            1.899822
# HouseAge         12.585558
# AveRooms          2.474173
# AveBedrms         0.473911
# Population     1132.462122
# AveOccup         10.386050
# Latitude          2.135952
# Longitude         2.003532
# MedHouseVal       1.153956
# dtype: float64
#
# Minimum values per column:
# MedInc           0.499900
# HouseAge         1.000000
# AveRooms         0.846154
# ...

# %%
boston_df['MedHouseValue'] = housing_dataset.target

boston_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal  MedHouseValue
# 0    -122.23        4.526          4.526
# 1    -122.22        3.585          3.585
# 2    -122.24        3.521          3.521
# 3    -122.25        3.413          3.413
# 4    -122.25        3.422          3.422

# %%
boston_df.drop(index=0, axis=0, inplace=False)  # inplace=False keeps original DataFrame

boston_df.drop(columns='HouseAge', axis=1, inplace=False)
# Out:
#        MedInc  AveRooms  AveBedrms  Population  AveOccup  Latitude  Longitude  \
# 0      8.3252  6.984127   1.023810       322.0  2.555556     37.88    -122.23
# 1      8.3014  6.238137   0.971880      2401.0  2.109842     37.86    -122.22
# 2      7.2574  8.288136   1.073446       496.0  2.802260     37.85    -122.24
# 3      5.6431  5.817352   1.073059       558.0  2.547945     37.85    -122.25
# 4      3.8462  6.281853   1.081081       565.0  2.181467     37.85    -122.25
# ...       ...       ...        ...         ...       ...       ...        ...
# 20635  1.5603  5.045455   1.133333       845.0  2.560606     39.48    -121.09
# 20636  2.5568  6.114035   1.315789       356.0  3.122807     39.49    -121.21
# 20637  1.7000  5.205543   1.120092      1007.0  2.325635     39.43    -121.22
# 20638  1.8672  5.329513   1.171920       741.0  2.123209     39.43    -121.32
# 20639  2.3886  5.254717   1.162264      1387.0  2.616981     39.37    -121.24
#
# ...

# %%
# Locate a specific row
print("Row at index 2:")
print(boston_df.iloc[2])

# Locate particular columns
print("\nFirst column:")
print(boston_df.iloc[:, 0])

print("\nSecond column:")
print(boston_df.iloc[:, 1])

print("\nThird column:")
print(boston_df.iloc[:, 2])

print("\nLast column:")
print(boston_df.iloc[:, -1])
# Out:
# Row at index 2:
# MedInc             7.257400
# HouseAge          52.000000
# AveRooms           8.288136
# AveBedrms          1.073446
# Population       496.000000
# AveOccup           2.802260
# Latitude          37.850000
# Longitude       -122.240000
# MedHouseVal        3.521000
# MedHouseValue      3.521000
# Name: 2, dtype: float64
#
# First column:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64
#
# Second column:
# 0        41.0
# 1        21.0
# 2        52.0
# 3        52.0
# 4        52.0
#          ...
# 20635    25.0
# 20636    18.0
# 20637    17.0
# 20638    18.0
# 20639    16.0
# Name: HouseAge, Length: 20640, dtype: float64
#
# Third column:
# 0        6.984127
# 1        6.238137
# 2        8.288136
# 3        5.817352
# 4        6.281853
#            ...
# ...

# %%
# Correlation: positive and negative correlations
corr_matrix = boston_df.corr()
print(corr_matrix)

# Optional: display correlation heatmap (requires seaborn)
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap for California Housing Dataset")
plt.show()
# Out:
#                  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc         1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge      -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms       0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms     -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population     0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup       0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude      -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude     -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal    0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
# MedHouseValue  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#                Latitude  Longitude  MedHouseVal  MedHouseValue
# ...
